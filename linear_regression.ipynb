# %% [markdown]
# <a href="https://colab.research.google.com/github/shreykinshu/Bus-Reservation-System/blob/master/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1:

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/lab_file/Car_Buy.csv")
inputs = df.drop('Buy',axis='columns')
target = df['Buy']
print(inputs)
print(target)
# Out:
#       Age Mileage Road tested
# 0  Recent     Low         Yes
# 1  Recent    High         Yes
# 2     Old     Low          No
# 3  Recent    High          No
# 0    1
# 1    1
# 2    0
# 3    0
# Name: Buy, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_Age = LabelEncoder()
le_Mileage = LabelEncoder()
le_RoadTested = LabelEncoder()
input_n=pd.DataFrame()
input_n['Age_n'] = le_Age.fit_transform(inputs['Age'])
input_n['Mileage_n'] = le_Mileage.fit_transform(inputs['Mileage'])
input_n['RoadTested_n'] = le_RoadTested.fit_transform(inputs['Road tested'])
print(input_n)
# Out:
#    Age_n  Mileage_n  RoadTested_n
# 0      1          1             1
# 1      1          0             1
# 2      0          1             0
# 3      1          0             0

# %%
target
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# Name: Buy, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='entropy')
model.fit(input_n, target)
model.score(input_n,target)
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,12))
a = plot_tree(model, feature_names=df.columns, fontsize=12, filled=True, 
              class_names=['1', '0'])
